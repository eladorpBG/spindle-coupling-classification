# %%
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
set_visualize_provider(InlineProvider())
import os
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

from interpret.glassbox import ExplainableBoostingClassifier
from interpret import show

# %%
adults_model_path = os.path.join("ebm_results_adults", "ebm_model.pkl")
children_model_path = os.path.join("ebm_results_children", "ebm_model.pkl")

with open(adults_model_path, "rb") as f:
    adults_model = pickle.load(f)
with open(children_model_path, "rb") as f:
    children_model = pickle.load(f)

# %%
show(children_model.explain_global())
# Out:
#     <div id="_interpret-viz-a10a4ee5-6d3c-4f93-ab7e-aee8d37eccc9"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
# ...

# %%
from interpret.provider import DashProvider
from interpret import set_visualize_provider

# Use .from_address() to set the IP and Port
set_visualize_provider(DashProvider.from_address(('0.0.0.0', 7002)))

show(children_model.explain_global())
# Out:
# <!-- http://0.0.0.0:7002/139968465921600/ -->
# <iframe src="http://0.0.0.0:7002/139968465921600/" width=100% height=800 frameBorder="0"></iframe>
